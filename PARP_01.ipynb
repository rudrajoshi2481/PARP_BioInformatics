# %%
import pandas as pd
import numpy as np

# %%
csv_data = "./PARP_protein_info.csv"

# %%
df_parp = pd.read_csv(csv_data)

# %%
df_parp.shape
# Out:
# (6063, 46)

# %%
type(df_parp)
# Out:
# pandas.core.frame.DataFrame

# %%
df_parp.head()
# Out:
#   Molecule ChEMBL ID Molecule Name  Molecule Max Phase  Molecular Weight  \
# 0       CHEMBL133694           NaN                 NaN            161.16
# 1       CHEMBL338790           NaN                 NaN            212.21
# 2       CHEMBL379251           NaN                 NaN            404.51
# 3       CHEMBL202313           NaN                 NaN            419.48
# 4       CHEMBL380648           NaN                 NaN            380.42
#
#    #RO5 Violations  AlogP Compound Key  \
# 0              0.0   0.66           19
# 1              0.0   1.31    4-amino-1
# 2              0.0   3.48           25
# 3              0.0   3.34            6
# 4              0.0   2.09            4
#
#                                               Smiles Standard Type  \
# 0                             NC(=O)c1cccc2[nH]cnc12            Ki
# 1                                                NaN           NaN
# 2    CCCN1CCCN(C(=O)c2cccc(Cc3nnc(O)c4ccccc34)c2)CC1          IC50
# ...

# %%
df_parp_IC50 = df_parp[df_parp["Standard Type"] == "IC50"]

# %%
df_parp_IC50.shape
# Out:
# (3165, 46)

# %%
# now filter it using the standard unit 
# locate how many standard unit
# Standard Type               3165 non-null   object 
#  9   Standard Relation           3074 non-null   object 
#  10  Standard Value              3074 non-null   float64
#  11  Standard Units  
df_parp_IC50["Standard Units"].unique()
# Out:
# array(['nM', nan, "10'8nM", "10'13nM", 'ug.mL-1'], dtype=object)

# %%
# Standard unit nM
df_parp_IC50_nM = df_parp_IC50[df_parp_IC50["Standard Units"] == "nM"]
df_parp_IC50_nM["Standard Units"].unique()
# Out:
# array(['nM'], dtype=object)

# %%
df_parp_IC50_nM["Standard Relation"].unique()
# Out:
# array(["'='", "'>'", "'<'"], dtype=object)

# %%
df_parp_IC50_nM = df_parp_IC50_nM[df_parp_IC50_nM["Standard Relation"]  ==  "'='"]
df_parp_IC50_nM["Standard Relation"].unique()
# Out:
# array(["'='"], dtype=object)

# %%
df_parp_IC50_nM.shape
# Out:
# (2747, 46)

# %%
df_parp_IC50_nM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2747 entries, 2 to 6061
# Data columns (total 46 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Molecule ChEMBL ID          2747 non-null   object
#  1   Molecule Name               178 non-null    object
#  2   Molecule Max Phase          144 non-null    float64
#  3   Molecular Weight            2747 non-null   float64
#  4   #RO5 Violations             2746 non-null   float64
#  5   AlogP                       2746 non-null   float64
#  6   Compound Key                2747 non-null   object
#  7   Smiles                      2747 non-null   object
#  8   Standard Type               2747 non-null   object
#  9   Standard Relation           2747 non-null   object
#  10  Standard Value              2747 non-null   float64
#  11  Standard Units              2747 non-null   object
#  12  pChEMBL Value               2720 non-null   float64
# ...

# %%
# remove the compounds with smiles missing
df_parp_IC50_nM.dropna(axis=0,how="any",subset=["Smiles"])
# Out:
#      Molecule ChEMBL ID Molecule Name  Molecule Max Phase  Molecular Weight  \
# 2          CHEMBL379251           NaN                 NaN            404.51
# 3          CHEMBL202313           NaN                 NaN            419.48
# 5          CHEMBL560528           NaN                 NaN            391.42
# 6          CHEMBL123205           NaN                 NaN            164.21
# 19          CHEMBL45245           NaN                 NaN            195.22
# ...                 ...           ...                 ...               ...
# 6056      CHEMBL5175745           NaN                 NaN            563.62
# 6057      CHEMBL5207585           NaN                 NaN            591.67
# 6059       CHEMBL521686      OLAPARIB                 4.0            434.47
# 6060      CHEMBL5190481           NaN                 NaN            418.88
# 6061      CHEMBL5197101           NaN                 NaN            405.50
#
#       #RO5 Violations  AlogP Compound Key  \
# ...

# %%
df_parp_IC50_nM.shape
# Out:
# (2747, 46)

# %%
df_parp_IC50_nM["Target Organism"].unique()
# Out:
# array(['Homo sapiens', nan], dtype=object)

# %%
df_parp_IC50_nM.dropna(axis=0,how="any",subset=["Target Organism"])
# Out:
#      Molecule ChEMBL ID Molecule Name  Molecule Max Phase  Molecular Weight  \
# 2          CHEMBL379251           NaN                 NaN            404.51
# 3          CHEMBL202313           NaN                 NaN            419.48
# 5          CHEMBL560528           NaN                 NaN            391.42
# 6          CHEMBL123205           NaN                 NaN            164.21
# 19          CHEMBL45245           NaN                 NaN            195.22
# ...                 ...           ...                 ...               ...
# 6056      CHEMBL5175745           NaN                 NaN            563.62
# 6057      CHEMBL5207585           NaN                 NaN            591.67
# 6059       CHEMBL521686      OLAPARIB                 4.0            434.47
# 6060      CHEMBL5190481           NaN                 NaN            418.88
# 6061      CHEMBL5197101           NaN                 NaN            405.50
#
#       #RO5 Violations  AlogP Compound Key  \
# ...

# %%
df_parp_IC50_nM["Target Organism"].unique()
# Out:
# array(['Homo sapiens', nan], dtype=object)

# %%
df_parp_IC50_nM.shape
# Out:
# (2747, 46)

# %%
df_parp_IC50_nM["Action Type"].unique()
# Out:
# array([nan, 'INHIBITOR', 'DEGRADER'], dtype=object)

# %%
df_parp_IC50_nM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2747 entries, 2 to 6061
# Data columns (total 46 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Molecule ChEMBL ID          2747 non-null   object
#  1   Molecule Name               178 non-null    object
#  2   Molecule Max Phase          144 non-null    float64
#  3   Molecular Weight            2747 non-null   float64
#  4   #RO5 Violations             2746 non-null   float64
#  5   AlogP                       2746 non-null   float64
#  6   Compound Key                2747 non-null   object
#  7   Smiles                      2747 non-null   object
#  8   Standard Type               2747 non-null   object
#  9   Standard Relation           2747 non-null   object
#  10  Standard Value              2747 non-null   float64
#  11  Standard Units              2747 non-null   object
#  12  pChEMBL Value               2720 non-null   float64
# ...
